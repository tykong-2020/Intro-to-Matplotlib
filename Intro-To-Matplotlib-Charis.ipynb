# %%
import matplotlib
print(f'Matplotlib: {matplotlib.__version__}')
import matplotlib.pyplot as plt # load in matplotlib plotting tools
import pandas as pd # rename as pd by convention
print(f"pandas: {pd.__version__}")
import numpy as np  # rename as np by convention
print(f"numpy: {np.__version__}")
# Out:
# Matplotlib: 3.1.3
# pandas: 1.0.1
# numpy: 1.18.1

# %%
df = pd.read_csv("http://bit.ly/tcsv19")

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
# %matplotlib inline

fig, ax = plt.subplots()

_ = ax.plot(np.sort(df['age']), marker = 'o', markersize = 1)

# %%
ax.plot?

# %%
##########################################################

# %%
# %config InlineBackend.figure_format = 'retina'  # change this to png if your plots are too small
# %matplotlib inline                              # to show image in notebook
import matplotlib.pyplot as plt
import numpy as np
# Out:
# UsageError: unrecognized arguments: # to show image in notebook

# %%
import matplotlib
matplotlib.get_backend()

# %%
plt.figure()

# %%
plt.subplots()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12264d290>)

# %%
fig, ax = plt.subplots()

# %%
import pandas as pd
df = pd.read_csv("http://bit.ly/tcsv19")

# %%
fig1, ax = plt.subplots()
_ = ax.set_title ("Titanic Data Set")
_ = ax.plot(np.sort(df['age']), marker='o', markersize=1)
_ = ax.set_ylabel("Ages")
_ = ax.set_xlabel("Passengers")
_ = ax.set_yticks([15, 25, 55, 64])

# %%
fig1, ax = plt.subplots()
_ = ax.set_title ("Titanic Data Set")
_ = ax.plot(np.sort(df['age']), marker='o', markersize=1)
_ = ax.set_ylabel("Ages")
_ = ax.set_xlabel("Passengers")
_ = ax.set_yticks([15, 25, 55, 64])
_ = ax.set_yticklabels(['children', 'youth', 'adults', 'seniors'])

# %%
fig1, ax = plt.subplots()
_ = ax.set_title ("Titanic Data Set")
_ = ax.plot(np.sort(df['fare']), marker='o', linestyle = "", markersize=10)
_ = ax.set_ylabel("Fare")
_ = ax.set_xlabel("Passengers")
_ = ax.set_yscale("log")                 # converts what follows into log scale
_ = ax.set_yticks([3, 12, 30, 870])
_ = ax.set_yticklabels(['3rd', '2nd', '1st Berth', '1st Suite'])

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows = 2, constrained_layout = True)
fig.suptitle('Next To (1x2)')
# Out:
# Text(0.5, 0.98, 'Next To (1x2)')

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2)         #left = ax1, right = ax2
fig.suptitle('Next To (1x2)')
# Out:
# Text(0.5, 0.98, 'Next To (1x2)')

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, gridspec_kw={'width_ratios':[1,3]}, constrained_layout = True)    
fig.suptitle('Next To (1x2)')
_ = ax1.plot(np.sort(df['age']), marker='o', markersize=1)
_ = ax1.set_ylabel("Ages")
_ = ax1.set_yticks([15,25, 55, 64])
_ = ax2.set_ylabel('Fare')

# %%
df = pd.read_csv('http://bit.ly/tcsv19').dropna()

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.00      0      0   24160  211.3375       B5        S
# 1   0.92      1      2  113781  151.5500  C22 C26        S
# 2   2.00      1      2  113781  151.5500  C22 C26        S
# 3  30.00      1      2  113781  151.5500  C22 C26        S
# 4  25.00      1      2  113781  151.5500  C22 C26        S

# %%
fig, ax = plt.subplots()
_ = ax.scatter('age', 'fare', data = df, color = 'pink')
_ = ax.set(xlabel = 'Age', ylabel = 'Fare', title = 'Titanic Passengers')

# %%
fig, ax = plt.subplots()
_ = ax.scatter('age', 'fare', c = 'survived',
               cmap = 'tab10', data = df)
_ = ax.set(xlabel = 'Age', ylabel = 'Fare', title = 'Titanic Passengers')

# %%
import matplotlib.colors as mcolors
cmap = mcolors.ListedColormap(['black', 'yellowgreen'])
fig, ax = plt.subplots()
_ = ax.scatter('age', 'fare', c='survived', cmap=cmap, data=df)
_ = ax.set(xlabel = 'Age', ylabel = 'Fare')

# %%
fig, ax = plt.subplots()
sc = ax.scatter('age', 'fare', c='survived', cmap=cmap, data=df)
_ = ax.set(xlabel = 'Age', ylabel = 'Fare')
_ =  ax.legend(*sc.legend_elements())     # * breaks list into individual elements

# %%
fig, ax = plt.subplots()
sc = ax.scatter('age', 'fare', c='survived', cmap=cmap, alpha = .5, edgecolor = 'k', data=df)
_ = ax.set(xlabel = 'Age', ylabel = 'Fare')
_ =  ax.legend(handles = sc.legend_elements()[0], 
              labels = ['Died', 'Survived'])

# %%
fig, ax = plt.subplots()
sc = ax.scatter('age', 'fare', c='survived', cmap=cmap, alpha = .5, edgecolor = 'k', data=df, s = df['pclass']*25)
_ = ax.set(xlabel = 'Age', ylabel = 'Fare')
_ =  ax.legend(handles = sc.legend_elements()[0], 
              labels = ['Died', 'Survived'])

# %%
fig, ax = plt.subplots()

sc = ax.scatter('age', 'fare', c='survived', cmap=cmap, alpha=.5, edgecolor='black', 
                marker='s',label='Female', data=df[df['sex'].str.match('female')])
sc2 = ax.scatter('age', 'fare', c='survived', cmap=cmap, alpha=.5, edgecolor='black', 
                marker='^',label='male', data=df[df['sex'].str.match('male')])

_ = ax.set(xlabel = 'Age', ylabel = 'Fare')
_ =  ax.legend(handles = sc.legend_elements()[0], labels=['Died', 'Survived'], fontsize = 14)

# %%
# %matplotlib widget
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
x, y, c, s = 'age', 'fare', 'survived', 'pclass'

_ = ax1.scatter(x, y, c=c, cmap=cmap, alpha=.5,  marker='s', data=df[df['sex'] =='male'])
_ = ax2.scatter(x, y, c=c, cmap=cmap, alpha=.5, marker='^', data=df[df['sex'] =='female'])
_ = ax1.set(ylabel=y, title='male')
_ = ax2.set(xlabel=x, ylabel=y, title='female')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-a18ad7c0f627> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'widget')
#       2 fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
#       3 x, y, c, s = 'age', 'fare', 'survived', 'pclass'
#       4
#       5 _ = ax1.scatter(x, y, c=c, cmap=cmap, alpha=.5,  marker='s', data=df[df['sex'] =='male'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2315                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2316             with self.builtin_trap:
# -> 2317                 result = fn(*args, **kwargs)
#    2318             return result
#    2319
#
# </Users/apple/opt/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-108> in matplotlib(self, line)
#
# ...

# %%
#######################Pie & Bar Charts########################

# %%
survived = df['survived'].value_counts()
survived

# %%
fig, ax = plt.subplots()
_ = ax.pie(x = survived.values, labels = ['survived', 'died'], colors = ['yellowgreen', 'black'])

# %%
pclass = df['sex'].value_counts()
pclass.index

# %%
pclass.values

# %%
fig, ax = plt.subplots()
_ = ax.bar(pclass.index, pclass.values)

# %%
###########################Images##########################

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
im = np.load('data/dem.npy')

# %%
print(f"type: {type(im)}, shape: {im.shape}, dtype: {im.dtype}")
# Out:
# type: <class 'numpy.ndarray'>, shape: (324, 368), dtype: float32

# %%
plt.imshow(im)

# %%
fig, ax = plt.subplots()
img = ax.imshow(im)
cbar = fig.colorbar(img)
cbar.set_label('Elevation')

# %%
fig, ax = plt.subplots()
img = ax.imshow(im, vmin=700, vmax = 1000)
cbar = fig.colorbar(img)
cbar.set_label('Elevation')

# %%
fig, ax = plt.subplots()
img = ax.imshow(im, cmap='magma')
cbar = fig.colorbar(img)
cbar.set_label('Elevation')

# %%
fig, ax = plt.subplots()
img = ax.imshow(im, cmap='jet')
cbar = fig.colorbar(img)
cbar.set_label('Elevation')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex = True, sharey = True)
ax1.contour(im, cmap ='magma', levels = 20)
ax1.set_aspect('equal')
ax2.imshow(im, cmap ='magma', origin ='lower')      # put (0, 0) on the lower left to match contour

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex = True, sharey = True)
ax1.contourf(im, cmap ='magma')
ax1.set_aspect('equal')
ax2.imshow(im, cmap ='magma', origin ='lower')      # put (0, 0) on the lower left to match contour

# %%
from matplotlib.colors import LogNorm

# take the 2D fft of our test image and re-order to put 0 frequency in the center
spike = np.abs(np.fft.fftshift(np.fft.fft2(im)))

fig, (ax1, ax2) = plt.subplots(1, 2, tight_layout=True, figsize=(10, 5))

lin_im = ax1.imshow(spike)
_ = fig.colorbar(lin_im, ax=ax1)
_ = ax1.set_title('linear color scale')

log_im = ax2.imshow(spike, norm=LogNorm())
_ = fig.colorbar(log_im, ax=ax2)
_ = ax2.set_title('log color scale')

# %%
import matplotlib.colors as mcolors
import matplotlib.cm as mcm

cmap = mcm.tab20b
norm = mcolors.BoundaryNorm([1, 3, 4, 5, 7, 9, 12, 15, 20], cmap.N)

data = np.arange(20).reshape((1, 20))

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 6))

top = ax1.imshow(data, cmap=cmap, aspect='auto')
fig.colorbar(top, ax=ax1)
bottom = ax2.imshow(data, norm=norm, cmap=cmap, aspect='auto')
fig.colorbar(bottom, ax=ax2)
